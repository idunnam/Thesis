# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
season = 'MAM'

# %%
ACCESS_a = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/ACCESS_anomaly_'+season+'.nc')
HADGEM_cloud_a = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/HADGEM_anomaly_'+season+'_cloud.nc')
HADGEM_a = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/HADGEM_anomaly_'+season+'.nc')
CSIRO_a  = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/CSIRO_anomaly_'+season+'.nc')
IPSL_a   = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/IPSL_anomaly_'+season+'.nc')
MIROC5_a = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/MIROC5_anomaly_'+season+'.nc')
NORESM_a = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/NORESM_anomaly_'+season+'.nc')

#CMIP6 models
CESM_a      = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/CESM_anomaly_'+season+'.nc')
CNRM_ESM2_a = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/CNRM_ESM2_anomaly_'+season+'.nc')
CNRM_CM6_a = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/CNRM_CM6_anomaly_'+season+'.nc')
MRI_a       = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/MRI_anomaly_'+season+'.nc')
UKMO_a      = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/UKMO_anomaly_'+season+'.nc')

# %%
ACCESS = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/ACCESS_anomaly_'+season+'.nc')
HADGEM_cloud = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/HADGEM_anomaly_'+season+'_cloud.nc')
HADGEM = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/HADGEM_anomaly_'+season+'.nc')
CSIRO  = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/CSIRO_anomaly_'+season+'.nc')
IPSL   = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/IPSL_anomaly_'+season+'.nc')
MIROC5 = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/MIROC5_anomaly_'+season+'.nc')
NORESM = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/NORESM_anomaly_'+season+'.nc')

#CMIP6 models
CESM      = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/CESM_anomaly_'+season+'.nc')
CNRM_ESM2 = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/CNRM_ESM2_anomaly_'+season+'.nc')
CNRM_CM6 = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/CNRM_CM6_anomaly_'+season+'.nc')
MRI       = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/MRI_anomaly_'+season+'.nc')
UKMO      = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/SEB_anomalies_seasonal/UKMO_anomaly_'+season+'.nc')

# %%
ACCESS = ACCESS.mean(dim=['X10_105', 'Y21_199'])
HADGEM = HADGEM.mean(dim=['X10_105', 'Y21_199'])
CSIRO  = CSIRO.mean(dim=['X10_105', 'Y21_199'])
IPSL   = IPSL.mean(dim=['X10_105', 'Y21_199'])
MIROC5 = MIROC5.mean(dim=['X10_105', 'Y21_199'])
NORESM = NORESM.mean(dim=['X10_105', 'Y21_199'])

# %%
CESM = CESM.mean(dim=['X10_105', 'Y21_199'])
CNRM_ESM2 = CNRM_ESM2.mean(dim=['X10_105', 'Y21_199'])
CNRM_CM6 = CNRM_CM6.mean(dim=['X10_105', 'Y21_199'])
MRI = MRI.mean(dim=['X10_105', 'Y21_199'])
UKMO = UKMO.mean(dim=['X10_105', 'Y21_199'])

# %%
ACCESS.TT.plot()
HADGEM.TT.plot()
CSIRO.TT.plot()  
IPSL.TT.plot()   
MIROC5.TT.plot() 
NORESM.TT.plot() 
CESM.TT.plot() 
CNRM_ESM2.TT.plot() 
CNRM_CM6.TT.plot() 
MRI.TT.plot() 
UKMO.TT.plot()

# %%
ACCESS = ACCESS.rolling(year=20,center= True).mean()
HADGEM = HADGEM.rolling(year=20,center= True).mean()
CSIRO  = CSIRO.rolling(year=20,center= True).mean()
IPSL   = IPSL.rolling(year=20,center= True).mean()
MIROC5 = MIROC5.rolling(year=20,center= True).mean()
NORESM = NORESM.rolling(year=20,center= True).mean()

CESM = CESM.rolling(year=20,center= True).mean()
CNRM_ESM2 = CNRM_ESM2.rolling(year=20,center= True).mean()
CNRM_CM6 = CNRM_CM6.rolling(year=20,center= True).mean()
MRI = MRI.rolling(year=20,center= True).mean()
UKMO = UKMO.rolling(year=20,center= True).mean()

# %%
"""
ACCESS = ACCESS.rolling(year=10,center= True).mean()
HADGEM = HADGEM.rolling(year=10,center= True).mean()
CSIRO  = CSIRO.rolling(year=10,center= True).mean()
IPSL   = IPSL.rolling(year=10,center= True).mean()
MIROC5 = MIROC5.rolling(year=10,center= True).mean()
NORESM = NORESM.rolling(year=10,center= True).mean()

CESM = CESM.rolling(year=10,center= True).mean()
CNRM_ESM2 = CNRM_ESM2.rolling(year=10,center= True).mean()
CNRM_CM6 = CNRM_CM6.rolling(year=10,center= True).mean()
MRI = MRI.rolling(year=10,center= True).mean()
UKMO = UKMO.rolling(year=10,center= True).mean()
"""
# Out:
# '\nACCESS = ACCESS.rolling(year=10,center= True).mean()\nHADGEM = HADGEM.rolling(year=10,center= True).mean()\nCSIRO  = CSIRO.rolling(year=10,center= True).mean()\nIPSL   = IPSL.rolling(year=10,center= True).mean()\nMIROC5 = MIROC5.rolling(year=10,center= True).mean()\nNORESM = NORESM.rolling(year=10,center= True).mean()\n\nCESM = CESM.rolling(year=10,center= True).mean()\nCNRM_ESM2 = CNRM_ESM2.rolling(year=10,center= True).mean()\nCNRM_CM6 = CNRM_CM6.rolling(year=10,center= True).mean()\nMRI = MRI.rolling(year=10,center= True).mean()\nUKMO = UKMO.rolling(year=10,center= True).mean()\n'

# %%
ACCESS.TT.plot(label='ACCESS')
HADGEM.TT.plot(label='HADGEM') 
CSIRO.TT.plot(label='CSIRO')  
IPSL.TT.plot(label='IPSL')   
MIROC5.TT.plot(label='MIROC5') 
NORESM.TT.plot(label='NORESM')
plt.legend()

# %%
CESM.TT.plot(label='CESM') 
CNRM_ESM2.TT.plot(label='CNRM-ESM2') 
CNRM_CM6.TT.plot(label='CNRM-CM6') 
MRI.TT.plot(label='MRI')
UKMO.TT.plot(label='UKESM') 
plt.legend()

# %%
TAS = [1.5, 2.0 ,2.5, 3.0, 3.5]
for i in range(0,5):
    print('Season:',season)
    print('TAS:', TAS[i])
    print('Model','     year', '     interval', '     mean', '     std')
    print('--------------------------------------------------')
    print('ACCESS   :',np.int(ACCESS.year.where((ACCESS.TT >=TAS[i])).dropna(dim='year')[0].values),
         ' (',
         np.int(ACCESS.year.where((ACCESS.TT >=TAS[i])).dropna(dim='year')[0].values - 10),
          '-',
          np.int(ACCESS.year.where((ACCESS.TT >=TAS[i])).dropna(dim='year')[0].values + 10),
          ')   ',
          np.round((ACCESS.sel(year=slice(
              str(np.int(ACCESS.year.where((ACCESS.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(ACCESS.year.where((ACCESS.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
          '    ',
          np.round(np.std((ACCESS.sel(year=slice(
              str(np.int(ACCESS.year.where((ACCESS.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(ACCESS.year.where((ACCESS.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT)).values,2))
         
         

         
    print('HADGEM   :',np.int(HADGEM.year.where((HADGEM.TT >=TAS[i])).dropna(dim='year')[0].values),
         ' (',
         np.int(HADGEM.year.where((HADGEM.TT >=TAS[i])).dropna(dim='year')[0].values - 10),
          '-',
          np.int(HADGEM.year.where((HADGEM.TT >=TAS[i])).dropna(dim='year')[0].values + 10),
          ')   ',
          np.round((HADGEM.sel(year=slice(
              str(np.int(HADGEM.year.where((HADGEM.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(HADGEM.year.where((HADGEM.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
          '    ',
          np.round(np.std((HADGEM.sel(year=slice(
              str(np.int(HADGEM.year.where((HADGEM.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(HADGEM.year.where((HADGEM.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT)).values,2))
               
    
  
    print('CSIRO    :',np.int(CSIRO.year.where((CSIRO.TT >=TAS[i])).dropna(dim='year')[0].values),
         ' (',
         np.int(CSIRO.year.where((CSIRO.TT >=TAS[i])).dropna(dim='year')[0].values - 10),
          '-',
          np.int(CSIRO.year.where((CSIRO.TT >=TAS[i])).dropna(dim='year')[0].values + 10),
          ')   ',
          np.round((CSIRO.sel(year=slice(
              str(np.int(CSIRO.year.where((CSIRO.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(CSIRO.year.where((CSIRO.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
          '    ',
          np.round(np.std((CSIRO.sel(year=slice(
              str(np.int(CSIRO.year.where((CSIRO.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(CSIRO.year.where((CSIRO.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT)).values,2))
    
    
    print('IPSL     :',np.int(IPSL.year.where((IPSL.TT >=TAS[i])).dropna(dim='year')[0].values),
         ' (',
         np.int(IPSL.year.where((IPSL.TT >=TAS[i])).dropna(dim='year')[0].values - 10),
          '-',
          np.int(IPSL.year.where((IPSL.TT >=TAS[i])).dropna(dim='year')[0].values + 10),
          ')   ',
          np.round((IPSL.sel(year=slice(
              str(np.int(IPSL.year.where((IPSL.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(IPSL.year.where((IPSL.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
          '    ',
          np.round(np.std((IPSL.sel(year=slice(
              str(np.int(IPSL.year.where((IPSL.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(IPSL.year.where((IPSL.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT)).values,2))
    
    
    print('MIROC5   :',np.int(MIROC5.year.where((MIROC5.TT >=TAS[i])).dropna(dim='year')[0].values),
         ' (',
         np.int(MIROC5.year.where((MIROC5.TT >=TAS[i])).dropna(dim='year')[0].values - 10),
          '-',
          np.int(MIROC5.year.where((MIROC5.TT >=TAS[i])).dropna(dim='year')[0].values + 10),
          ')   ',
          np.round((MIROC5.sel(year=slice(
              str(np.int(MIROC5.year.where((MIROC5.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(MIROC5.year.where((MIROC5.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
          '    ',
          np.round(np.std((MIROC5.sel(year=slice(
              str(np.int(MIROC5.year.where((MIROC5.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(MIROC5.year.where((MIROC5.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT)).values,2))
      
    print('NORESM   :',np.int(NORESM.year.where((NORESM.TT >=TAS[i])).dropna(dim='year')[0].values),
         ' (',
         np.int(NORESM.year.where((NORESM.TT >=TAS[i])).dropna(dim='year')[0].values - 10),
          '-',
          np.int(NORESM.year.where((NORESM.TT >=TAS[i])).dropna(dim='year')[0].values + 10),
          ')   ',
          np.round((NORESM.sel(year=slice(
              str(np.int(NORESM.year.where((NORESM.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(NORESM.year.where((NORESM.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
          '    ',
          np.round(np.std((NORESM.sel(year=slice(
              str(np.int(NORESM.year.where((NORESM.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(NORESM.year.where((NORESM.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT)).values,2))
      


    print('CESM     :',np.int(CESM.year.where((CESM.TT >=TAS[i])).dropna(dim='year')[0].values),
         ' (',
         np.int(CESM.year.where((CESM.TT >=TAS[i])).dropna(dim='year')[0].values - 10),
          '-',
          np.int(CESM.year.where((CESM.TT >=TAS[i])).dropna(dim='year')[0].values + 10),
          ')   ',
          np.round((CESM.sel(year=slice(
              str(np.int(CESM.year.where((CESM.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(CESM.year.where((CESM.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
          '    ',
          np.round(np.std((CESM.sel(year=slice(
              str(np.int(CESM.year.where((CESM.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(CESM.year.where((CESM.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT)).values,2))
      
    
    print('CNRM_ESM2:',np.int(CNRM_ESM2.year.where((CNRM_ESM2.TT >=TAS[i])).dropna(dim='year')[0].values),
         ' (',
         np.int(CNRM_ESM2.year.where((CNRM_ESM2.TT >=TAS[i])).dropna(dim='year')[0].values - 10),
          '-',
          np.int(CNRM_ESM2.year.where((CNRM_ESM2.TT >=TAS[i])).dropna(dim='year')[0].values + 10),
          ')   ',
          np.round((CNRM_ESM2.sel(year=slice(
              str(np.int(CNRM_ESM2.year.where((CNRM_ESM2.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(CNRM_ESM2.year.where((CNRM_ESM2.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
          '    ',
          np.round(np.std((CNRM_ESM2.sel(year=slice(
              str(np.int(CNRM_ESM2.year.where((CNRM_ESM2.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(CNRM_ESM2.year.where((CNRM_ESM2.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT)).values,2))
      
    print('CNRM_CM6 :',np.int(CNRM_CM6.year.where((CNRM_CM6.TT >=TAS[i])).dropna(dim='year')[0].values),
         ' (',
         np.int(CNRM_CM6.year.where((CNRM_CM6.TT >=TAS[i])).dropna(dim='year')[0].values - 10),
          '-',
          np.int(CNRM_CM6.year.where((CNRM_CM6.TT >=TAS[i])).dropna(dim='year')[0].values + 10),
          ')   ',
          np.round((CNRM_CM6.sel(year=slice(
              str(np.int(CNRM_CM6.year.where((CNRM_CM6.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(CNRM_CM6.year.where((CNRM_CM6.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
          '    ',
          np.round(np.std((CNRM_CM6.sel(year=slice(
              str(np.int(CNRM_CM6.year.where((CNRM_CM6.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(CNRM_CM6.year.where((CNRM_CM6.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT)).values,2))
     
    
    print('MRI      :',np.int(MRI.year.where((MRI.TT >=TAS[i])).dropna(dim='year')[0].values),
         ' (',
         np.int(MRI.year.where((MRI.TT >=TAS[i])).dropna(dim='year')[0].values - 10),
          '-',
          np.int(MRI.year.where((MRI.TT >=TAS[i])).dropna(dim='year')[0].values + 10),
          ')   ',
          np.round((MRI.sel(year=slice(
              str(np.int(MRI.year.where((MRI.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(MRI.year.where((MRI.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
          '    ',
          np.round(np.std((MRI.sel(year=slice(
              str(np.int(MRI.year.where((MRI.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(MRI.year.where((MRI.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT)).values,2))
     
    print('UKESM    :',np.int(UKMO.year.where((UKMO.TT >=TAS[i])).dropna(dim='year')[0].values),
         ' (',
         np.int(UKMO.year.where((UKMO.TT >=TAS[i])).dropna(dim='year')[0].values - 10),
          '-',
          np.int(UKMO.year.where((UKMO.TT >=TAS[i])).dropna(dim='year')[0].values + 10),
          ')   ',
          np.round((UKMO.sel(year=slice(
              str(np.int(UKMO.year.where((UKMO.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(UKMO.year.where((UKMO.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
          '    ',
          np.round(np.std((UKMO.sel(year=slice(
              str(np.int(UKMO.year.where((UKMO.TT >=TAS[i])).dropna(dim='year')[0].values - 10)),
              str(UKMO.year.where((UKMO.TT >=TAS[i])).dropna(dim='year')[0].values + 10))).TT)).values,2))
     
    print('--------------------------------------------------')
    print('--------------------------------------------------')
# Out:
# Season: MAM
# TAS: 1.5
# Model      year      interval      mean      std
# --------------------------------------------------
# ACCESS   : 2044  ( 2034 - 2054 )    1.45      0.34
# HADGEM   : 2003  ( 1993 - 2013 )    1.42      0.39
# CSIRO    : 2059  ( 2049 - 2069 )    1.67      0.45
# IPSL     : 2022  ( 2012 - 2032 )    1.37      0.17
# MIROC5   : 2041  ( 2031 - 2051 )    1.65      0.45
# NORESM   : 2043  ( 2033 - 2053 )    1.42      0.37
# CESM     : 2036  ( 2026 - 2046 )    1.6      0.34
# CNRM_ESM2: 2036  ( 2026 - 2046 )    1.5      0.18
# CNRM_CM6 : 2042  ( 2032 - 2052 )    1.51      0.4
# MRI      : 2028  ( 2018 - 2038 )    1.49      0.15
# UKESM    : 2007  ( 1997 - 2017 )    1.4      0.53
# --------------------------------------------------
# --------------------------------------------------
# Season: MAM
# TAS: 2.0
# Model      year      interval      mean      std
# --------------------------------------------------
# ACCESS   : 2055  ( 2045 - 2065 )    1.99      0.25
# ...

# %%
#np.int(NORESM.year.where((NORESM.TT >=3)).dropna(dim='year')[0].values)
NORESM.TT[-10:]
# Out:
# <xarray.DataArray 'TT' (year: 10)>
# array([3.47236306,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan])
# Coordinates:
#   * year     (year) int64 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100

# %%
TAS = 3.0

print('Season:',season)
print('TAS:', TAS)
print('Model','     year', '     interval', '     mean', '     std','     std rol')
print('--------------------------------------------------------------')
print('ACCESS   :',np.int(ACCESS_a.year.where((ACCESS.TT >=TAS)).dropna(dim='year')[0].values),
      ' (',
      np.int(ACCESS_a.year.where((ACCESS.TT >=TAS)).dropna(dim='year')[0].values - 10),
      '-',
      np.int(ACCESS_a.year.where((ACCESS.TT >=TAS)).dropna(dim='year')[0].values + 10),
      ')   ',
      np.round((ACCESS_a.sel(year=slice(
          str(np.int(ACCESS_a.year.where((ACCESS.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(ACCESS_a.year.where((ACCESS.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
      '    ',
      np.round(np.std((ACCESS_a.sel(year=slice(
          str(np.int(ACCESS_a.year.where((ACCESS.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(ACCESS_a.year.where((ACCESS.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2),
      '    ',
      np.round(np.std((ACCESS.sel(year=slice(
          str(np.int(ACCESS.year.where((ACCESS.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(ACCESS.year.where((ACCESS.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2))
         

         
print('HADGEM   :',np.int(HADGEM_a.year.where((HADGEM.TT >=TAS)).dropna(dim='year')[0].values),
      ' (',
      np.int(HADGEM_a.year.where((HADGEM.TT >=TAS)).dropna(dim='year')[0].values - 10),
      '-',
      np.int(HADGEM_a.year.where((HADGEM.TT >=TAS)).dropna(dim='year')[0].values + 10),
      ')   ',
      np.round((HADGEM_a.sel(year=slice(
          str(np.int(HADGEM_a.year.where((HADGEM.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(HADGEM_a.year.where((HADGEM.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
      '    ',
      np.round(np.std((HADGEM_a.sel(year=slice(
          str(np.int(HADGEM_a.year.where((HADGEM.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(HADGEM_a.year.where((HADGEM.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2),
      '    ',
      np.round(np.std((HADGEM.sel(year=slice(
          str(np.int(HADGEM.year.where((HADGEM.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(HADGEM.year.where((HADGEM.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2))
               
print('CSIRO    :',np.int(CSIRO_a.year.where(CSIRO.year.sel(year=slice('2090','2090'))).values),
      ' (',
      np.int(CSIRO_a.year.where(CSIRO.year.sel(year=slice('2090','2090'))).values - 10),
      '-',
      np.int(CSIRO_a.year.where(CSIRO.year.sel(year=slice('2090','2090'))).values + 10),
      ')   ',
      np.round((CSIRO_a.sel(year=slice(
          str(np.int(CSIRO_a.year.where(CSIRO.year.sel(year=slice('2090','2090'))).values - 10)),
          str(CSIRO_a.year.where(CSIRO.year.sel(year=slice('2090','2090'))).values + 10))).TT.mean()).values,2),
      '    ',
      np.round(np.std((CSIRO_a.sel(year=slice(
          str(np.int(CSIRO_a.year.where(CSIRO.year.sel(year=slice('2090','2090'))).values - 10)),
          str(CSIRO_a.year.where(CSIRO.year.sel(year=slice('2090','2090'))).values + 10))).TT)).values,2),
      '    ',
      np.round(np.std((CSIRO.sel(year=slice(
          str(np.int(CSIRO.year.where(CSIRO.year.sel(year=slice('2090','2090'))).values - 10)),
          str(CSIRO.year.where(CSIRO.year.sel(year=slice('2090','2090'))).values + 10))).TT)).values,2))

      
    
print('IPSL     :',np.int(IPSL_a.year.where((IPSL.TT >=TAS)).dropna(dim='year')[0].values),
      ' (',
      np.int(IPSL_a.year.where((IPSL.TT >= TAS)).dropna(dim='year')[0].values - 10),
      '-',
      np.int(IPSL_a.year.where((IPSL.TT >= TAS)).dropna(dim='year')[0].values + 10),
      ')   ',
      np.round((IPSL_a.sel(year=slice(
          str(np.int(IPSL_a.year.where((IPSL.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(IPSL_a.year.where((IPSL.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
      '    ',
      np.round(np.std((IPSL_a.sel(year=slice(
          str(np.int(IPSL_a.year.where((IPSL.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(IPSL_a.year.where((IPSL.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2),
      '    ',
      np.round(np.std((IPSL.sel(year=slice(
          str(np.int(IPSL.year.where((IPSL.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(IPSL.year.where((IPSL.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2))
        
print('MIROC5   :',np.int(MIROC5_a.year.where((MIROC5.TT >=TAS)).dropna(dim='year')[0].values),
      ' (',
      np.int(MIROC5_a.year.where((MIROC5.TT >=TAS)).dropna(dim='year')[0].values - 10),
      '-',
      np.int(MIROC5_a.year.where((MIROC5.TT >=TAS)).dropna(dim='year')[0].values + 10),
      ')   ',
      np.round((MIROC5_a.sel(year=slice(
          str(np.int(MIROC5_a.year.where((MIROC5.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(MIROC5_a.year.where((MIROC5.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
      '    ',
      np.round(np.std((MIROC5_a.sel(year=slice(
          str(np.int(MIROC5_a.year.where((MIROC5.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(MIROC5_a.year.where((MIROC5.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2),
      '    ',
      np.round(np.std((MIROC5.sel(year=slice(
          str(np.int(MIROC5.year.where((MIROC5.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(MIROC5.year.where((MIROC5.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2))
      
print('NORESM   :',np.int(NORESM_a.year.where((NORESM.TT >=TAS)).dropna(dim='year')[0].values),
      ' (',
      np.int(NORESM_a.year.where((NORESM.TT >=TAS)).dropna(dim='year')[0].values - 10),
      '-',
      np.int(NORESM_a.year.where((NORESM.TT >=TAS)).dropna(dim='year')[0].values + 10),
      ')   ',
      np.round((NORESM_a.sel(year=slice(
          str(np.int(NORESM_a.year.where((NORESM.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(NORESM_a.year.where((NORESM.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
      '    ',
      np.round(np.std((NORESM_a.sel(year=slice(
          str(np.int(NORESM_a.year.where((NORESM.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(NORESM_a.year.where((NORESM.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2),
      '    ',
      np.round(np.std((NORESM.sel(year=slice(
          str(np.int(NORESM.year.where((NORESM.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(NORESM.year.where((NORESM.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2))
     
      


print('CESM     :',np.int(CESM_a.year.where((CESM.TT >=TAS)).dropna(dim='year')[0].values),
      ' (',
      np.int(CESM_a.year.where((CESM.TT >=TAS)).dropna(dim='year')[0].values - 10),
      '-',
      np.int(CESM_a.year.where((CESM.TT >=TAS)).dropna(dim='year')[0].values + 10),
      ')   ',
      np.round((CESM_a.sel(year=slice(
          str(np.int(CESM_a.year.where((CESM.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(CESM_a.year.where((CESM.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
      '    ',
      np.round(np.std((CESM_a.sel(year=slice(
          str(np.int(CESM_a.year.where((CESM.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(CESM_a.year.where((CESM.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2),
      '    ',
      np.round(np.std((CESM.sel(year=slice(
          str(np.int(CESM.year.where((CESM.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(CESM.year.where((CESM.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2))
      
    
print('CNRM_ESM2:',np.int(CNRM_ESM2_a.year.where((CNRM_ESM2.TT >=TAS)).dropna(dim='year')[0].values),
      ' (',
      np.int(CNRM_ESM2_a.year.where((CNRM_ESM2.TT >=TAS)).dropna(dim='year')[0].values - 10),
      '-',
      np.int(CNRM_ESM2_a.year.where((CNRM_ESM2.TT >=TAS)).dropna(dim='year')[0].values + 10),
      ')   ',
      np.round((CNRM_ESM2_a.sel(year=slice(
          str(np.int(CNRM_ESM2_a.year.where((CNRM_ESM2.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(CNRM_ESM2_a.year.where((CNRM_ESM2.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
      '    ',
      np.round(np.std((CNRM_ESM2_a.sel(year=slice(
          str(np.int(CNRM_ESM2_a.year.where((CNRM_ESM2.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(CNRM_ESM2_a.year.where((CNRM_ESM2.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2),
      '    ',
      np.round(np.std((CNRM_ESM2.sel(year=slice(
          str(np.int(CNRM_ESM2.year.where((CNRM_ESM2.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(CNRM_ESM2.year.where((CNRM_ESM2.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2))
      
print('CNRM_CM6 :',np.int(CNRM_CM6_a.year.where((CNRM_CM6.TT >=TAS)).dropna(dim='year')[0].values),
      ' (',
      np.int(CNRM_CM6_a.year.where((CNRM_CM6.TT >=TAS)).dropna(dim='year')[0].values - 10),
      '-',
      np.int(CNRM_CM6_a.year.where((CNRM_CM6.TT >=TAS)).dropna(dim='year')[0].values + 10),
      ')   ',
      np.round((CNRM_CM6_a.sel(year=slice(
          str(np.int(CNRM_CM6_a.year.where((CNRM_CM6.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(CNRM_CM6_a.year.where((CNRM_CM6.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
      '    ',
      np.round(np.std((CNRM_CM6_a.sel(year=slice(
          str(np.int(CNRM_CM6_a.year.where((CNRM_CM6.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(CNRM_CM6_a.year.where((CNRM_CM6.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2),
      '     ',
      np.round(np.std((CNRM_CM6.sel(year=slice(
          str(np.int(CNRM_CM6.year.where((CNRM_CM6.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(CNRM_CM6.year.where((CNRM_CM6.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2))
          
    
print('MRI      :',np.int(MRI_a.year.where((MRI.TT >=TAS)).dropna(dim='year')[0].values),
      ' (',
      np.int(MRI_a.year.where((MRI.TT >=TAS)).dropna(dim='year')[0].values - 10),
      '-',
       np.int(MRI_a.year.where((MRI.TT >=TAS)).dropna(dim='year')[0].values + 10),
       ')   ',
       np.round((MRI_a.sel(year=slice(
          str(np.int(MRI_a.year.where((MRI.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(MRI_a.year.where((MRI.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
    '    ',
       np.round(np.std((MRI_a.sel(year=slice(
          str(np.int(MRI_a.year.where((MRI.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(MRI_a.year.where((MRI.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2),
    '    ',
       np.round(np.std((MRI.sel(year=slice(
          str(np.int(MRI.year.where((MRI.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(MRI.year.where((MRI.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2))
     
print('UKESM    :',np.int(UKMO_a.year.where((UKMO.TT >=TAS)).dropna(dim='year')[0].values),
      ' (',
      np.int(UKMO_a.year.where((UKMO.TT >=TAS)).dropna(dim='year')[0].values - 10),
      '-',
      np.int(UKMO_a.year.where((UKMO.TT >=TAS)).dropna(dim='year')[0].values + 10),
      ')   ',
      np.round((UKMO_a.sel(year=slice(
          str(np.int(UKMO_a.year.where((UKMO.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(UKMO_a.year.where((UKMO.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT.mean()).values,2),
      '     ',
      np.round(np.std((UKMO_a.sel(year=slice(
          str(np.int(UKMO_a.year.where((UKMO.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(UKMO_a.year.where((UKMO.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2),
      '     ',
      np.round(np.std((UKMO.sel(year=slice(
          str(np.int(UKMO.year.where((UKMO.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(UKMO.year.where((UKMO.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2))     
print('--------------------------------------------------------------')
print('--------------------------------------------------------------')
# Out:
# Season: MAM
# TAS: 3.0
# Model      year      interval      mean      std      std rol
# --------------------------------------------------------------
# ACCESS   : 2070  ( 2060 - 2080 )    3.21      2.14      0.76
# HADGEM   : 2039  ( 2029 - 2049 )    3.08      1.49      0.33
# CSIRO    : 2090  ( 2080 - 2100 )    3.44      1.83      0.12
# IPSL     : 2062  ( 2052 - 2072 )    3.23      1.82      0.45
# MIROC5   : 2064  ( 2054 - 2074 )    3.09      1.57      0.43
# NORESM   : 2076  ( 2066 - 2086 )    3.06      1.33      0.33
# CESM     : 2058  ( 2048 - 2068 )    3.01      1.85      0.4
# CNRM_ESM2: 2070  ( 2060 - 2080 )    3.06      1.72      0.61
# CNRM_CM6 : 2061  ( 2051 - 2071 )    3.11      1.8       0.67
# MRI      : 2053  ( 2043 - 2063 )    3.03      1.46      0.19
# UKESM    : 2041  ( 2031 - 2051 )    3.1       1.8       0.47
# --------------------------------------------------------------
# --------------------------------------------------------------

# %%
 np.round(np.std((ACCESS_a.sel(year=slice(
          str(np.int(ACCESS_a.year.where((ACCESS.TT >=TAS)).dropna(dim='year')[0].values - 10)),
          str(ACCESS_a.year.where((ACCESS.TT >=TAS)).dropna(dim='year')[0].values + 10))).TT)).values,2))

# %%
ACCESS.TT[-10:]
# Out:
# <xarray.DataArray 'TT' (year: 10)>
# array([4.18200039,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan])
# Coordinates:
#   * year     (year) int64 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100

# %%
#UKMO = UKMO.mean(dim=['X10_105','Y21_199'])
UKMO_time      = UKMO.rolling(year=20,center= True).mean(dim=['X10_105','Y21_199'])
# Out:
# /opt/conda/lib/python3.7/site-packages/xarray/core/nanops.py:140: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)

# %%
plt.plot(UKMO_time.year, UKMO_time.TT)

# %%
#plt.boxplot(UKMO_rol_4.TT)
#plt.boxplot(UKMO_rol_4.TT.mean(dim=['X10_105','Y21_199']))
plt.boxplot(UKMO.TT.sel(year=slice('2029','2049')))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff444605f28>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff44460db70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff444605dd8>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff444613400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff444613828>],
#  'means': []}

# %%
NORESM_rol_4 = xr.open_dataset('/mnt/mcc-ns9600k/idunnam/src/rol_mean_3_5_deg/NORESM_rol_4.nc').mean(dim='year')
# Out:
# /opt/conda/lib/python3.7/site-packages/xarray/core/nanops.py:140: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)

# %%
N = NORESM_rol_4

# %%
#N.AL2.where((N.SMB>0)&(N.SMB0)).plot()
T = N.AL2 - N.AL2.where(N.SMB>0) - N.AL2.where(N.SMB<10)
